# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
#
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```
#
#
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
# import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# >The `imdb.csv` dataset contains Highest Rated IMDb "Top 1000" Titles.

# %%
# load imdb dataset as pandas dataframe
imdb=pd.read_csv("imdb_1000.csv",encoding='latin1')
imdb
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# show first 5 rows of imdb_df
imdb.head()
imdb
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# >The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012.

# %%
# load bikes dataset as pandas dataframe
bikes=pd.read_csv('bikes.csv',delimiter=';', encoding='latin1',parse_dates=['Date'], dayfirst=True)
bikes
# Out:
#           Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0   2012-01-01      00:00                 16      35             51
# 1   2012-01-02      00:00                 43      83            153
# 2   2012-01-03      00:00                 58     135            248
# 3   2012-01-04      00:00                 61     144            318
# 4   2012-01-05      00:00                 95     197            330
# ..         ...        ...                ...     ...            ...
# 361 2012-12-27      00:00                  8      12              7
# 362 2012-12-28      00:00                  0      35              3
# 363 2012-12-29      00:00                  0      27              8
# 364 2012-12-30      00:00                  0       5              1
# 365 2012-12-31      00:00                  0       4              3
#
#      Maisonneuve_1  BrÃ©beuf  Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  \
# 0               38       5.0    26       10                             0
# ...

# %%
# show first 3 rows of bikes_df
e=bikes.head(3)
e
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
#
#             Maisonneuve_1  BrÃ©beuf  Parc  PierDup  \
# Date
# 2012-01-01             38       5.0    26       10
# 2012-01-02             68      11.0    53        6
# 2012-01-03            104       2.0    89        3
#
#             CSC (CÃ´te Sainte-Catherine)  Pont_Jacques_Cartier        Date
# Date
# 2012-01-01                             0                  27.0  2012-01-01
# 2012-01-02                             1                  21.0  2012-01-01
# 2012-01-03                             2                  15.0  2012-01-01

# %% [markdown]
# ### Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
# list columns of imdb_df
imdb.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# what are the datatypes of values in columns
print(imdb.dtypes)
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# list first 5 movie titles
imdb[['title']].head()
# Out:
#                       title
# 0  The Shawshank Redemption
# 1             The Godfather
# 2    The Godfather: Part II
# 3           The Dark Knight
# 4              Pulp Fiction

# %%
# show only movie title and genre
imdb[['title','genre']]
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
# show the type of duration column
print(type(imdb['duration']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# show duration values of movies as numpy arrays
d=imdb[['duration']].to_numpy()
d
# Out:
# array([[142],
#        [175],
#        [200],
#        [152],
#        [154],
#        [161],
#        [201],
#        [195],
#        [139],
#        [178],
#        [148],
#        [124],
#        [142],
#        [179],
#        [169],
#        [133],
#        [207],
#        [146],
#        [121],
#        [136],
#        [130],
#        [130],
#        [127],
#        [175],
#        [125],
#        [169],
#        [189],
#        [150],
#        [165],
#        [155],
#        [137],
#        [165],
#        [151],
#        [155],
#        [153],
#        [125],
#        [130],
#        [137],
#        [165],
#        [170],
#        [146],
#        [156],
#        [122],
#        [149],
#        [134],
#        [122],
#        [136],
#        [157],
#        [123],
#        [137],
#        [128],
#        [120],
#        [229],
#        [134],
#        [177],
#        [129],
#        [216],
#        [136],
#        [189],
#        [181],
#        [138],
#        [129],
# ...

# %% [markdown]
# ## Applying functions to columns
#
# Use `.apply` function to apply any function to each element of a column.

# %%
# convert all the movie titles to uppercase
imdb['title']=imdb['title'].str.upper()
imdb['title']
# Out:
# 0                             THE SHAWSHANK REDEMPTION
# 1                                        THE GODFATHER
# 2                               THE GODFATHER: PART II
# 3                                      THE DARK KNIGHT
# 4                                         PULP FICTION
#                             ...
# 967                                           THE ROCK
# 968                                THE ENGLISH PATIENT
# 973                              THE CIDER HOUSE RULES
# 976    MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 978                                        WALL STREET
# Name: title, Length: 454, dtype: object

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# plot the bikers travelling to Berri1 over the ye
bikes.plot(x='Date', y='Berri1',title="No of bikers to Berri1 over the year",figsize=(30,10))

# %%
# plot all the columns of bikes_df
bikes.plot(subplots=True,grid=True,figsize=(10,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFC0DBAB08>,
# ...
#       dtype=object)

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
# what are the unique genre in imdb_df?
print(imdb.genre.unique())
u=imdb.genre.nunique()
u
# Out:
# ['Crime' 'Action' 'Drama' 'Western' 'Adventure' 'Biography' 'Comedy'
#  'Animation' 'Mystery' 'Horror' 'Film-Noir' 'Sci-Fi' 'History' 'Thriller'
#  'Family' 'Fantasy']
# 16

# %%
# plotting value counts of unique genres as a bar chart
imdb['genre'].value_counts().plot(kind='bar',title='Genres',figsize=(10,5))

# %%
# plotting value counts of unique genres as a pie chart
imdb['genre'].value_counts().plot(kind='pie',radius=1,title='Genres',figsize=(20,10))

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
# show index of bikes_df
bikes.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
# get row for date 2012-01-01
bikes[bikes['Date']=="2012-01-01"]
# Out:
#         Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0 2012-01-01      00:00                 16      35             51
#
#    Maisonneuve_1  BrÃ©beuf  Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  \
# 0             38       5.0    26       10                             0
#
#    Pont_Jacques_Cartier
# 0                  27.0

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
# show 11th row of imdb_df using iloc
row_11=imdb.iloc[11]
row_11
# Out:
# star_rating                                                     8.8
# title                                                     Inception
# content_rating                                                PG-13
# genre                                                        Action
# duration                                                        148
# actors_list       [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# Name: 11, dtype: object

# %% [markdown]
# ## Selecting rows where column has a particular value

# %%
# select only those movies where genre is advendf[df['W']>0]['Y']
imdb[imdb['genre']=='Adventure']['title']
# Out:
# 7          THE LORD OF THE RINGS: THE RETURN OF THE KING
# 10     THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# 14                 THE LORD OF THE RINGS: THE TWO TOWERS
# 15                                          INTERSTELLAR
# 54                                    BACK TO THE FUTURE
#                              ...
# 936                                            TRUE GRIT
# 937                                            LABYRINTH
# 943                                      THE BUCKET LIST
# 953                                THE NEVERENDING STORY
# 975                          BACK TO THE FUTURE PART III
# Name: title, Length: 75, dtype: object

# %%
imdb[imdb.genre=='Adventure']
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 68           8.4                                           Das Boot
# 71           8.4                                 North by Northwest
# 85           8.4                                 Lawrence of Arabia
# 114          8.3                               Inglourious Basterds
# 120          8.3                                   The Great Escape
# 133          8.3                                             Barfi!
# 137          8.3                       The Bridge on the River Kwai
# 140          8.3                                  The Wages of Fear
# 142          8.3                  Lagaan: Once Upon a Time in India
# ...

# %%
# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?
imdb[(imdb['star_rating']>8) & (imdb['duration']>130)]['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 273    Biography
# 288        Drama
# 289        Drama
# 290        Crime
# 296       Action
# Name: genre, Length: 115, dtype: object

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
# add a weekday column to bikes_d
bikes['weekday']=bikes['Date'].dt.day_name()
bikes
# Out:
#           Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0   2012-01-01      00:00                 16      35             51
# 1   2012-01-02      00:00                 43      83            153
# 2   2012-01-03      00:00                 58     135            248
# 3   2012-01-04      00:00                 61     144            318
# 4   2012-01-05      00:00                 95     197            330
# ..         ...        ...                ...     ...            ...
# 361 2012-12-27      00:00                  8      12              7
# 362 2012-12-28      00:00                  0      35              3
# 363 2012-12-29      00:00                  0      27              8
# 364 2012-12-30      00:00                  0       5              1
# 365 2012-12-31      00:00                  0       4              3
#
#      Maisonneuve_1  BrÃ©beuf  Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  \
# 0               38       5.0    26       10                             0
# ...

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
# remove column 'Unnamed: 1' from bikes_df
z=bikes.drop('Unnamed: 1',axis=1)
z
# Out:
#           Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0   2012-01-01                 16      35             51             38
# 1   2012-01-02                 43      83            153             68
# 2   2012-01-03                 58     135            248            104
# 3   2012-01-04                 61     144            318            116
# 4   2012-01-05                 95     197            330            124
# ..         ...                ...     ...            ...            ...
# 361 2012-12-27                  8      12              7              4
# 362 2012-12-28                  0      35              3             38
# 363 2012-12-29                  0      27              8             42
# 364 2012-12-30                  0       5              1              5
# 365 2012-12-31                  0       4              3              8
#
#      BrÃ©beuf  Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
# remove row no. 1 from bikes_df
z.drop([1],axis=0)
# Out:
#           Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0   2012-01-01                 16      35             51             38
# 2   2012-01-03                 58     135            248            104
# 3   2012-01-04                 61     144            318            116
# 4   2012-01-05                 95     197            330            124
# 5   2012-01-06                 75     146            244             98
# ..         ...                ...     ...            ...            ...
# 361 2012-12-27                  8      12              7              4
# 362 2012-12-28                  0      35              3             38
# 363 2012-12-29                  0      27              8             42
# 364 2012-12-30                  0       5              1              5
# 365 2012-12-31                  0       4              3              8
#
#      BrÃ©beuf  Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
# group imdb_df by movie genres
by_genres=imdb.groupby('genre')
by_genres

# %%
by_genres.count()
# Out:
#            star_rating  title  content_rating  duration  actors_list
# genre
# Action             136    136             135       136          136
# Adventure           75     75              74        75           75
# Animation           62     62              62        62           62
# Biography           77     77              76        77           77
# Comedy             156    156             156       156          156
# Crime              124    124             124       124          124
# Drama              278    278             278       278          278
# Family               2      2               2         2            2
# Fantasy              1      1               1         1            1
# Film-Noir            3      3               3         3            3
# History              1      1               1         1            1
# Horror              29     29              29        29           29
# ...

# %%
# get crime movies group
by_genres.get_group('Crime')
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
# get mean of movie durations for each group
d_mean=imdb.groupby(['genre']).mean()
d_mean['duration']
# Out:
# genre
# Action       141.373333
# Adventure    154.304348
# Animation    126.333333
# Biography    143.019231
# Comedy       136.181818
# Crime        141.683333
# Drama        142.362500
# Horror       129.200000
# Mystery      135.571429
# Sci-Fi       132.000000
# Thriller     120.000000
# Western      148.571429
# Name: duration, dtype: float64

# %%
# change duration of all movies in a particular genre to mean duration of the group
crime=imdb.groupby('genre').get_group('Crime')
crime['duration']=crime['duration'].mean()
crime[['title','duration']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 title    duration
# 0            The Shawshank Redemption  141.683333
# 1                       The Godfather  141.683333
# 2              The Godfather: Part II  141.683333
# 4                        Pulp Fiction  141.683333
# 21                        City of God  141.683333
# 40                     The Green Mile  141.683333
# 49                       The Departed  141.683333
# 78        Once Upon a Time in America  141.683333
# 86                 A Clockwork Orange  141.683333
# ...

# %%
# drop groups/genres that do not have average movie duration greater than 120. 
y=imdb.drop(imdb[imdb.duration<120].index,inplace=True)
print(y)
imdb
# Out:
# None
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
# group weekday wise bikers count
grp=bikes.groupby('weekday').sum()

# %%
grp=bikes.groupby('weekday')
grp.first()
# Out:
#                 Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# weekday
# Friday    2012-01-06      00:00                 75     146            244
# Monday    2012-01-02      00:00                 43      83            153
# Saturday  2012-01-07      00:00                 54      98            108
# Sunday    2012-01-01      00:00                 16      35             51
# Thursday  2012-01-05      00:00                 95     197            330
# Tuesday   2012-01-03      00:00                 58     135            248
# Wednesday 2012-01-04      00:00                 61     144            318
#
#            Maisonneuve_1  BrÃ©beuf  Parc  PierDup  \
# weekday
# Friday                98       4.0    86        4
# Monday                68      11.0    53        6
# Saturday              80       5.0    53        6
# Sunday                38       5.0    26       10
# Thursday             124       6.0    97       13
# Tuesday              104       2.0    89        3
# ...

# %%
# get weekday wise biker count
grp
# Out:
#            Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  BrÃ©beuf  \
# weekday
# Friday                146979  150493         183961         104584   12259.0
# Monday                138881  142285         174610          95565   15436.0
# Saturday              118560  105635         109902          64872   11170.0
# Sunday                122115  102447         102272          57438   12032.0
# Thursday              150971  169976         210039         118633   15679.0
# Tuesday               131632  145795         179939          99421   10629.0
# Wednesday             144531  163603         200273         112344   14876.0
#
#              Parc  PierDup  CSC (CÃ´te Sainte-Catherine)  Pont_Jacques_Cartier
# weekday
# Friday      96569    43217                         59856               62164.0
# Monday      97001    47259                         64011               74692.0
# Saturday    51019    53360                         35507               54493.0
# ...

# %%
# plot weekday wise biker count for 'Berri1'
bikes.plot(x='weekday',y='Berri1',title='weekday wise biker count for Berril1',figsize=(10,5))

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
